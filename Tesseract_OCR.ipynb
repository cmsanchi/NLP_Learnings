# %% [markdown]
# <a href="https://colab.research.google.com/github/cmsanchi/NLP_Learnings/blob/main/Tesseract_OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir('/content/drive/MyDrive/')

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 15 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 1s (4,467 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# !sudo apt-get install tesseract-ocr-kor
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tesseract-ocr-kor
# 0 upgraded, 1 newly installed, 0 to remove and 15 not upgraded.
# Need to get 1,050 kB of archives.
# After this operation, 1,693 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-kor all 4.00~git24-0e00fe6-1.2 [1,050 kB]
# Fetched 1,050 kB in 1s (1,247 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %%
# !sudo apt-get install tesseract-ocr-tel
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tesseract-ocr-tel
# 0 upgraded, 1 newly installed, 0 to remove and 15 not upgraded.
# Need to get 1,013 kB of archives.
# After this operation, 2,784 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-tel all 4.00~git24-0e00fe6-1.2 [1,013 kB]
# Fetched 1,013 kB in 1s (1,341 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c68e4af2-63be-4edf-8f63-fbfb9003bed0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c68e4af2-63be-4edf-8f63-fbfb9003bed0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving chat.jpg to chat (1).jpg

# %%
image_path_in_colab='chat.jpg'
extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_colab))
print(extractedInformation)
# Out:
# 4:36 ®
#
#
#
# <@ Grammar Engine
# S,S,S, You
#
# Can we use attention layer for sentiment
#
# analysis? 9:20 AM W
# | don't have any encoder and decoder
# 9:21 AM W
# S Sourabh
#
# Yes, we have a sequence right 9.2
#
#
#
# We can use attention 9.2; a
#
# Yes | have 0:22 am wv
# Can you share one sample? 9.22 am wv
#
# | simply created model with Bilstm
#
# followed by dense 9:22 AM W/
#
# But Val accuracy is 87, training accuracy
#
# 98 9:23 AM W/
# S Sourabh
#
# You can add simple Dot product
# Attention, as we used for emoji
#
#
#
# prediction 9:27 AM
# Okay 9:27 am w/
# Let me check 9.27 am w
# S Sourabh
# keras-self-attention
# python Attention mechanism for processing
# “P sequential data that considers the c...
# Pypl.org
# https://pypi.org/project/keras- eet ¥
# -attention/
#
#
#
# Hl O <

# %%
image = Image.open("youtube.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x1200 at 0x7FDBBF745518>

# %%
string = pytesseract.image_to_string(image, lang='eng')

# %%
string
# Out:
# '4\n\n© oulube S| @a &\n\n      \n\nSwitch to a Career in\nStL R Te\n\n \n\n \n\nBecome a Software Development Expert\n\nM.Tech in Software Development | In\nweekend-classroom format for working professio...\n\nPES University\n\n \n\nTee Naga Chaitanya NON - STOP Punches On\n#Samantha @ SAM - JAM Show | #Chaysam...\nTrend Telugu - 69K views - 2 hours ago\n\n \n\n@ chnctn\n(\n\nHome Explore @ Subscriptions Library\nIl O <\n\n \n\n \n\n \n\n \n\x0c'

# %%
string = pytesseract.image_to_string(image, lang='tel')
string
# Out:
# '14\n\n1001100 వ) [9890 ట్ర\n\n      \n\nవ\nన\n\n \n\n \n\n8600006 & 50[1//2/6 ౦అ/6100౧౧6౧1 ద(౧6గ\n\n14.600 1౧ 5010//86 06/6100౧౧౪౧1 | 1౧\n1/661606-01295/000) 10౧0081 10! ౪/0161౧0 ౧౧౦1659510...\n\n౧౬౯5 ౮౧|/6910\n\n \n\n28 11202 0౧4120)/8 1101 - 570౧ ౧౪౮౧౦౧౪5 0౧\n52080008 (బ 514 - ౮4[4 500౪ | *0[2/98౧...\n76౧6 7616006 - 696 /164/5 - 2 ౧౦0౮౧౩ ౭౦౦\n\n \n\nఉలి 01౧4౧\n1\n\nగంగా ద10/8 ( 5050/10110౧5 0౧\n||| 09 క\n\n \n\n \n\n \n\n \n\x0c'

# %%
bank = Image.open("bank.jpg")
bank
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=626x1280 at 0x7FDBB7C7F5C0>

# %%
string = pytesseract.image_to_string(bank, lang='eng')
string
# Out:
# 'oe) peed EET aL\n\nTransfer Details\nReference No. (UTR No./RRN)\n100414883862\n\nDate & Time\n\n4 Jan 2021-02:15 PM\nTransfer Amount\n9,650.00\n\nBeneficiary name\nMadhuri Chandramouli\nBank name\n\nHDFC BANK\n\nAccount number\n23771870000328\n\nIFSC\n\nHDFC0002377\n\nRemarks\nDec\n\x0c'

# %%
chat = Image.open("chat.jpg")
chat
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x1200 at 0x7FDBB7C7AC50>

# %%
string = pytesseract.image_to_string(chat, lang='eng')
string
# Out:
# "4:36 ®\n\n   \n\n<@ Grammar Engine\nS,S,S, You\n\nCan we use attention layer for sentiment\n\nanalysis? 9:20 AM W\n| don't have any encoder and decoder\n9:21 AM W\nS Sourabh\n\nYes, we have a sequence right 9.2\n\n \n\nWe can use attention 9.2; a\n\nYes | have 0:22 am wv\nCan you share one sample? 9.22 am wv\n\n| simply created model with Bilstm\n\nfollowed by dense 9:22 AM W/\n\nBut Val accuracy is 87, training accuracy\n\n98 9:23 AM W/\nS Sourabh\n\nYou can add simple Dot product\nAttention, as we used for emoji\n\n \n\nprediction 9:27 AM\nOkay 9:27 am w/\nLet me check 9.27 am w\nS Sourabh\nkeras-self-attention\npython Attention mechanism for processing\n“P sequential data that considers the c...\nPypl.org\nhttps://pypi.org/project/keras- eet ¥\n-attention/\n\n  \n\nHl O <\n\x0c"

# %%
naver = Image.open("naver.jpg")
naver
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x1200 at 0x7FDBB7BCD198>

# %%
string = pytesseract.image_to_string(naver, lang='kor')
string
# Out:
# '0\n\n(서열 느/이이!\n\n \n\n매체크 맘마 0 6\n\n케스 든은\n\nㅇㅇ\n\n                                                                                                                                                                                                 \n\n \n\n경희사이버대학교\n21학년도 1학기 신.편입생 모집 중!\n\n \n\n0" 대구\n미세보통-초미세나\n\n \n\n날씨 내 위치찾7\n\n  \n\n \n\n \n\n눌러\n\n \n\n위치 찾        치의 시간대별주간\n\n날씨와 미세먼지 0               보세요\n\n \n\n여기에서\n\n \n\n티6니와\n\n \n\x0c'

# %%
string = pytesseract.image_to_string(naver)
string
# Out:
# '5:34 @\n\ncame Mumare\\is erin)\n\n \n\narjae! Dray Ge\n\nNAVER\n\nC\n\n   \n\n \n\nBolajojsicyeta\n21SHAS 19})| Amey 24 BS!\n\n \n\nO° He\nDA AS - 20] LS\n\n \n\nEEA Ly 21x) 217\n\n  \n\n \n\n \n\n24 ¢\n\n \n\netn 32 ZO] AIZECH #21\n\nEMO} OAH] 0 MIS\n\n \n\nO47 [0414\n\n \n\nENGLISH\n\n \n\x0c'
